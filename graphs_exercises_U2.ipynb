# %% [markdown]
# # Unit 2: Centrality metrics

# %%
# !pip install networkx
import networkx as nx
# Out:
# ...
#   Using cached networkx-3.2.1-py3-none-any.whl.metadata (5.2 kB)
# Using cached networkx-3.2.1-py3-none-any.whl (1.6 MB)
# ...

# %% [markdown]
# ## Exercise 12

# %%
G1 = nx.Graph()
# add edges from an edge list
G1.add_edges_from([(1,2), (1,3), (1,0), (2,3),(3,4),(0,4)])

# draw the graph
import matplotlib.pyplot as plt
nx.draw_networkx(G1, with_labels=True)
plt.show()

# %%
nx.degree_centrality(G1)
# Out:
# {1: 0.75, 2: 0.5, 3: 0.75, 0: 0.5, 4: 0.5}

# %%
nx.betweenness_centrality(G1, normalized = False)
# Out:
# {1: 1.5, 2: 0.0, 3: 1.5, 0: 0.5, 4: 0.5}

# %%
nx.closeness_centrality(G1)
# Out:
# {1: 0.8,
#  2: 0.6666666666666666,
#  3: 0.8,
#  0: 0.6666666666666666,
#  4: 0.6666666666666666}

# %% [markdown]
# ## Exercise 13

# %%
G = nx.karate_club_graph()
nx.draw_circular(G, with_labels=True)
plt.show()

# %%
nx.degree_centrality(G)
# Out:
# {0: 0.48484848484848486,
#  1: 0.2727272727272727,
#  2: 0.30303030303030304,
#  3: 0.18181818181818182,
#  4: 0.09090909090909091,
#  5: 0.12121212121212122,
#  6: 0.12121212121212122,
#  7: 0.12121212121212122,
#  8: 0.15151515151515152,
#  9: 0.06060606060606061,
#  10: 0.09090909090909091,
#  11: 0.030303030303030304,
#  12: 0.06060606060606061,
#  13: 0.15151515151515152,
#  14: 0.06060606060606061,
#  15: 0.06060606060606061,
#  16: 0.06060606060606061,
#  17: 0.06060606060606061,
#  18: 0.06060606060606061,
#  19: 0.09090909090909091,
#  20: 0.06060606060606061,
#  21: 0.06060606060606061,
#  22: 0.06060606060606061,
#  23: 0.15151515151515152,
#  24: 0.09090909090909091,
#  25: 0.09090909090909091,
#  26: 0.06060606060606061,
#  27: 0.12121212121212122,
#  28: 0.09090909090909091,
#  29: 0.12121212121212122,
#  30: 0.12121212121212122,
#  31: 0.18181818181818182,
#  32: 0.36363636363636365,
#  33: 0.5151515151515151}

# %%
nx.betweenness_centrality(G, normalized = False)
# Out:
# {0: 231.0714285714286,
#  1: 28.478571428571424,
#  2: 75.85079365079366,
#  3: 6.288095238095237,
#  4: 0.3333333333333333,
#  5: 15.833333333333334,
#  6: 15.833333333333332,
#  7: 0.0,
#  8: 29.529365079365082,
#  9: 0.44761904761904764,
#  10: 0.3333333333333333,
#  11: 0.0,
#  12: 0.0,
#  13: 24.215873015873015,
#  14: 0.0,
#  15: 0.0,
#  16: 0.0,
#  17: 0.0,
#  18: 0.0,
#  19: 17.1468253968254,
#  20: 0.0,
#  21: 0.0,
#  22: 0.0,
#  23: 9.299999999999999,
#  24: 1.1666666666666665,
#  25: 2.0277777777777777,
#  26: 0.0,
#  27: 11.79206349206349,
#  28: 0.9476190476190476,
#  29: 1.5428571428571427,
#  30: 7.609523809523807,
#  31: 73.00952380952378,
#  32: 76.69047619047619,
#  33: 160.5515873015873}

# %%
nx.closeness_centrality(G)
# Out:
# {0: 0.5689655172413793,
#  1: 0.4852941176470588,
#  2: 0.559322033898305,
#  3: 0.4647887323943662,
#  4: 0.3793103448275862,
#  5: 0.38372093023255816,
#  6: 0.38372093023255816,
#  7: 0.44,
#  8: 0.515625,
#  9: 0.4342105263157895,
#  10: 0.3793103448275862,
#  11: 0.36666666666666664,
#  12: 0.3707865168539326,
#  13: 0.515625,
#  14: 0.3707865168539326,
#  15: 0.3707865168539326,
#  16: 0.28448275862068967,
#  17: 0.375,
#  18: 0.3707865168539326,
#  19: 0.5,
#  20: 0.3707865168539326,
#  21: 0.375,
#  22: 0.3707865168539326,
#  23: 0.39285714285714285,
#  24: 0.375,
#  25: 0.375,
#  26: 0.3626373626373626,
#  27: 0.4583333333333333,
#  28: 0.4520547945205479,
#  29: 0.38372093023255816,
#  30: 0.4583333333333333,
#  31: 0.5409836065573771,
#  32: 0.515625,
#  33: 0.55}

# %%
nx.eigenvector_centrality(G)
# Out:
# {0: 0.35548349418519426,
#  1: 0.2659538704545024,
#  2: 0.3171893899684447,
#  3: 0.21117407832057056,
#  4: 0.0759664588165738,
#  5: 0.07948057788594245,
#  6: 0.07948057788594245,
#  7: 0.1709551149803543,
#  8: 0.22740509147166046,
#  9: 0.10267519030637756,
#  10: 0.0759664588165738,
#  11: 0.05285416945233646,
#  12: 0.08425192086558085,
#  13: 0.22646969838808145,
#  14: 0.10140627846270832,
#  15: 0.10140627846270832,
#  16: 0.02363479426059687,
#  17: 0.0923967566684595,
#  18: 0.10140627846270832,
#  19: 0.14791134007618667,
#  20: 0.10140627846270832,
#  21: 0.0923967566684595,
#  22: 0.10140627846270832,
#  23: 0.15012328691726787,
#  24: 0.057053735638028055,
#  25: 0.0592082025027901,
#  26: 0.07558192219009324,
#  27: 0.13347932684333308,
#  28: 0.13107925627221215,
#  29: 0.13496528673866567,
#  30: 0.17476027834493088,
#  31: 0.191036269797917,
#  32: 0.3086510477336959,
#  33: 0.37337121301323506}

# %% [markdown]
# ## Exercise 14 (checking results)

# %%
nx.clustering(G1)
# Out:
# {1: 0.3333333333333333, 2: 1.0, 3: 0.3333333333333333, 0: 0, 4: 0}

# %% [markdown]
# ## Exercise 15

# %%
from scipy.io import mmread
import networkx as nx
import matplotlib.pyplot as plt

# Load the adjacency matrix
fb_caltech_graph = mmread('socfb-Caltech36\socfb-Caltech36.mtx')

# Convert the sparse matrix to a dense NumPy array
adjacency_matrix = fb_caltech_graph.toarray()

# Create a NetworkX graph from the adjacency matrix
G = nx.from_numpy_array(adjacency_matrix)

# Visualize the graph
plt.figure(figsize=(10, 8))
nx.draw(G, with_labels=True, node_color='skyblue', node_size=200, edge_color='gray')
plt.title('Graph Visualization')
plt.show()

# %%
nx.clustering(G, 43)
# Out:
# 0.42063492063492064

# %% [markdown]
# ## Exercise 16

# %% [markdown]
# ## a)

# %%
G3 = nx.Graph()
# add edges from an edge list
G3.add_edges_from([(1,2), (1,4), (2,3), (3,4),(3,5),(5,6)])

# draw the graph
import matplotlib.pyplot as plt
nx.draw_networkx(G3, with_labels=True)
plt.show()

# %%
print(nx.radius(G3))
print(nx.diameter(G3))
# Out:
# 2
# 4

# %% [markdown]
# ## b)

# %%
import networkx as nx
import matplotlib.pyplot as plt

# Create a cycle graph with  7 nodes
G = nx.cycle_graph(7)

# Draw the graph
nx.draw(G, with_labels=True)
plt.show()

# %%
print(nx.radius(G))
print(nx.diameter(G))
# Out:
# 3
# 3

# %% [markdown]
# ## c)

# %%
G4 = nx.Graph()
# add edges from an edge list
G4.add_edges_from([(1,2), (1,4), (2,3), (3,4),(3,5)])

# draw the graph
import matplotlib.pyplot as plt
nx.draw_networkx(G4, with_labels=True)
plt.show()

# %%
print(nx.radius(G4))
print(nx.diameter(G4))
# Out:
# 2
# 3
